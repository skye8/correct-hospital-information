# %%
import numpy
testL=['a','b','c','d','e']
print(testL)
print(testL[:3])
print(testL[3:])
# Out:
# ['a', 'b', 'c', 'd', 'e']
# ['a', 'b', 'c']
# ['d', 'e']

# %%
###爬取宗旨就是：：： 
#（1）先读取  县数据表county_list  （id  county_name  city_id）
    #正常情况下要通过    city_id获取city_name   然后 http://www.a-hospital.com/w/ + city_name+county_name + 医院列表
    #非正常情况：  （1）url不一致：   http://www.a-hospital.com/w/ + county_name + 医院列表
                   #(2)页面不存在    没数据，直接为空，不写入数据库

# %%
import requests
from bs4 import BeautifulSoup

import pymysql
conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', 
                       passwd='', db='jiadesen', charset='utf8')
cursor = conn.cursor()

sql = "SELECT * FROM county_list"
cursor.execute(sql)
#county_all_info  内容包括(id,city_id,county_name)
county_all_info = cursor.fetchall()
#print(county_all_info)
print(len(county_all_info))


#county_all_info[:1]  测试第一个朝阳区   可以爬取该页面  ------------最正常的一般页面   必须写成【：1】这种形式
#county_all_info[2790:2971]    西藏自治区    日喀则地区    日喀则市--------------url只含有county_name   
                                #必须写成【2790:2791】   否则下面出错   each_info[0]会出错，类型估计不一致
    
                                #重庆市  永川市    county_all_info【43:44】     解决方案是添加了if  判断条件  判断value是否存在
#county_all_info[2266:2267]      江西省   景德镇市   珠山区-------------相应页面不存在的情况  ：：  直接不做处理，即没有任何东西
    

#for each_info in county_all_info[2790:2791]:
#for each_info in county_all_info[43:44]:
#for each_info in county_all_info[2266:2267]:
for each_info in county_all_info[865:]:
    tt_id = each_info[0]
    tt_city_id = each_info[1]
    tt_county_name = str(each_info[2])
    sql2 = "SELECT city_name FROM city_list WHERE id = %d "  %tt_city_id
    cursor.execute(sql2)
    tt_city_name = str(cursor.fetchone()[0])
    print(tt_id,tt_city_id,tt_county_name,tt_city_name)
    
    
    str1 = 'http://www.a-hospital.com/w/'
    str2 = tt_city_name + tt_county_name
    str3 = '医院列表'
    url = str1 + str2 + str3
    print(url)
    
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml')
    names = soup.select('ul > li > b > a')
    #print(names)
    informations = soup.select('ul > li > ul')
    #print(shengshi)
    print(len(names))
    print(len(informations))
    
    #################################################
    #需要添加第一个错误处理-----url直接是county_name
    if len(names) == 0:
        url = str1 + tt_county_name + str3
        print(url)
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'lxml')
        names = soup.select('ul > li > b > a')
        #print(names)
        informations = soup.select('ul > li > ul')
        #print(informations)
        print(len(names))
        print(len(informations))
        
        ### len(names)==0  针对该县页面不存在情况，直接不做处理即可
        if len(names)!=0:
            dict = {'hospital_name': 'None' ,'hospital_rank':'None ','hospital_property':'None'};
            #list=[]
            #print(dict)
            #print(list)

            for i in range(len(names)):
                name = names[i].find_parent('b').get_text()
                #print(name)
                dict['hospital_name'] = name
                #print(dict['hospital_name'])
                info = informations[i].select('li')
                for li in info:
                    if li.b:
                        title = li.b.get_text()
                        if title == "医院等级":
                            value = li.contents[1].replace('：', '')
                            if not value:
                                value = li.a.contents[0]
                            #print(li.a.contents[0])
                            #value = li.a.contents[0]
                            #print(title,":",value)
                            dict['hospital_rank'] = value
                            #print(dict['hospital_rank'])
                        elif title == "经营方式":
                            value2 = li.contents[1].replace('：', '')
                            if not value2:
                                value2 = li.a.contents[0]
                            #print(title,":",value2)
                            dict['hospital_property'] = value2
                            #print(dict['hospital_property'])
                
                print(dict)
                #print(tt_id)
                
                insert_sql = "INSERT INTO hospital_information(county_id, hospital_name, hospital_rank, hospital_property) VALUES(%s,%s,%s,%s)"
                #print(insert_sql,(tt_id,dict['hospital_name'],dict['hospital_rank'],dict['hospital_property']))
                cursor.execute(insert_sql,(tt_id,dict['hospital_name'],dict['hospital_rank'],dict['hospital_property']))
                conn.commit()
                
                dict = {'hospital_name': 'None' ,'hospital_rank':'None ','hospital_property':'None'}
            
        
        
    
    ###################################################
    
    else:
    
        dict = {'hospital_name': 'None' ,'hospital_rank':'None ','hospital_property':'None'};
        #list=[]
        #print(dict)
        #print(list)

        for i in range(len(names)):
            name = names[i].find_parent('b').get_text()
            #print(name)
            dict['hospital_name'] = name
            #print(dict['hospital_name'])
            info = informations[i].select('li')
            for li in info:
                if li.b:
                    title = li.b.get_text()
                    if title == "医院等级":
                        value = li.contents[1].replace('：', '')
                        if not value:
                            value = li.a.contents[0]
                        #print(title,":",value)
                        dict['hospital_rank'] = value
                        #print(dict['hospital_rank'])
                    elif title == "经营方式":
                        value2 = li.contents[1].replace('：', '')
                        if not value2:
                            value2 = li.a.contents[0]
                        #print(title,":",value2)
                        dict['hospital_property'] = value2
                        #print(dict['hospital_property'])
            
            print(dict)
            #print(tt_id)
          
            insert_sql = "INSERT INTO hospital_information(county_id, hospital_name, hospital_rank, hospital_property) VALUES(%s,%s,%s,%s)"
            #print(insert_sql,(tt_id,dict['hospital_name'],dict['hospital_rank'],dict['hospital_property']))
            cursor.execute(insert_sql,(tt_id,dict['hospital_name'],dict['hospital_rank'],dict['hospital_property']))
            conn.commit()
            
            dict = {'hospital_name': 'None' ,'hospital_rank':'None ','hospital_property':'None'}
# Out:
# 2863
# 866 87 宝丰县 平顶山市
# http://www.a-hospital.com/w/平顶山市宝丰县医院列表
# 4
# 4
# {'hospital_name': '宝丰县人民医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '宝丰县中医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '平顶山中心医院宝丰分院', 'hospital_rank': '二级乙等', 'hospital_property': '国营医院'}
# {'hospital_name': '宝丰铁路医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# 867 87 叶县 平顶山市
# http://www.a-hospital.com/w/平顶山市叶县医院列表
# 4
# 4
# {'hospital_name': '叶县人民医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '叶县中医院', 'hospital_rank': '二级乙等', 'hospital_property': '国营医院'}
# {'hospital_name': '叶县公费医疗医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# {'hospital_name': '叶县第二人民医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# 868 87 鲁山县 平顶山市
# http://www.a-hospital.com/w/平顶山市鲁山县医院列表
# 8
# 8
# {'hospital_name': '鲁山县中医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '鲁山县公费医疗医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '鲁山县人民医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '鲁山县公疗医院', 'hospital_rank': '一级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '鲁山国营江河机械厂职工医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# {'hospital_name': '鲁山县妇幼保健院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# {'hospital_name': '鲁山县同仁医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# {'hospital_name': '鲁山县中医医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# 869 87 郏县 平顶山市
# http://www.a-hospital.com/w/平顶山市郏县医院列表
# 5
# 5
# {'hospital_name': '郏县中医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name':
院', 'hospital_rank': '一级甲等', 'hospital_property': '国营医院'}
# 1439 151 丹江口市 十堰市
# http://www.a-hospital.com/w/十堰市丹江口市医院列表
# 0
# 0
# http://www.a-hospital.com/w/丹江口市医院列表
# 11
# 11
# {'hospital_name': '十堰市中医院', 'hospital_rank': '三级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '丹江口市第一医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '丹江口市妇幼保健院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '丹江口市第二医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '江口县人民医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '丹江口市中医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '丹江工程局职工医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '丹江口市第一人民医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '湖北省武当山医院', 'hospital_rank': '二级乙等', 'hospital_property': '国营医院'}
# {'hospital_name': '丹江口卫校附属医院', 'hospital_rank': '一级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '江口县民族中医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# 1440 151 郧县 十堰市
# http://www.a-hospital.com/w/十堰市郧县医院列表
# 4
# 4
# {'hospital_name': '郧县人民医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '郧县中医医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '郧县中医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# {'hospital_name': '郧县妇幼保健院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# 1441 151 竹山县 十堰市
# http://www.a-hospital.com/w/十堰市竹山县医院列表
# 5
# 5
# {'hospital_name': '竹山县中医医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '竹山县妇幼保健院', 'hospital_rank': '一级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '竹山县第二人民医院', 'hospital_rank': '一级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '竹山县人民医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# {'hospital_name': '竹山县中医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# 1442 151 房县 十堰市
# http://www.a-hospital.com/w/十堰市房县医院列表
# 3
# 3
# {'hospital_name': '房县人民医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '房县妇幼保健院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# {'hospital_name': '房县中医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# 1443 151 郧西县 十堰市
# http://www.a-hospital.com/w/十堰市郧西县医院列表
# 5
# 5
# {'hospital_name': '郧西县人民医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '郧西县中医医院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '郧西县妇幼保健院', 'hospital_rank': '二级甲等', 'hospital_property': '国营医院'}
# {'hospital_name': '郧西县中医院', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# {'hospital_name': '郧西县妇幼保健所', 'hospital_rank': 'None ', 'hospital_property': '国营医院'}
# 1444 151 竹溪县 十堰市
# http://www.a-hospital.com/w/十堰市竹溪县医院列表
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\Anaconda\anzhuang\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     136             conn = connection.create_connection(
# --> 137                 (self.host, self.port), self.timeout, **extra_kw)
#     138
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      90     if err is not None:
# ---> 91         raise err
#      92
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      80                 sock.bind(source_address)
# ---> 81             sock.connect(sa)
#      82             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\Anaconda\anzhuang\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     352         # urllib3.request. It also calls makefile (recv) on the socket.
# --> 353         conn.request(method, url, **httplib_request_kw)
#     354
#
# D:\Anaconda\anzhuang\lib\http\client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# D:\Anaconda\anzhuang\lib\http\client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# D:\Anaconda\anzhuang\lib\http\client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# D:\Anaconda\anzhuang\lib\http\client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# D:\Anaconda\anzhuang\lib\http\client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     161     def connect(self):
# --> 162         conn = self._new_conn()
#     163         self._prepare_conn(conn)
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     145             raise NewConnectionError(
# --> 146                 self, "Failed to establish a new connection: %s" % e)
#     147
#
# NewConnectionError: <requests.packages.urllib3.connection.HTTPConnection object at 0x0000000006F4A4A8>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\Anaconda\anzhuang\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     375                     retries=self.max_retries,
# --> 376                     timeout=timeout
#     377                 )
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     608             retries = retries.increment(method, url, error=e, _pool=self,
# --> 609                                         _stacktrace=sys.exc_info()[2])
#     610             retries.sleep()
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     272         if new_retry.is_exhausted():
# --> 273             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     274
#
# MaxRetryError: HTTPConnectionPool(host='www.a-hospital.com', port=80): Max retries exceeded with url: /w/%E5%8D%81%E5%A0%B0%E5%B8%82%E7%AB%B9%E6%BA%AA%E5%8E%BF%E5%8C%BB%E9%99%A2%E5%88%97%E8%A1%A8 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000000006F4A4A8>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-1-1df8c7eeb3a5> in <module>()
#      42     print(url)
#      43
# ---> 44     html = requests.get(url).text
#      45     soup = BeautifulSoup(html, 'lxml')
#      46     names = soup.select('ul > li > b > a')
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# D:\Anaconda\anzhuang\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     435                 raise RetryError(e, request=request)
#     436
# --> 437             raise ConnectionError(e, request=request)
#     438
#     439         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.a-hospital.com', port=80): Max retries exceeded with url: /w/%E5%8D%81%E5%A0%B0%E5%B8%82%E7%AB%B9%E6%BA%AA%E5%8E%BF%E5%8C%BB%E9%99%A2%E5%88%97%E8%A1%A8 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000000006F4A4A8>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))

# %%
##############################爬取 city_name+county_name 页面的医院数据

# -*- coding:utf-8 -*-
import requests
from bs4 import BeautifulSoup

url = 'http://www.a-hospital.com/w/北京市朝阳区医院列表'
html = requests.get(url).text
soup = BeautifulSoup(html, 'lxml')
names = soup.select('ul > li > b > a')
#print(names)
shengshi = soup.select('ul > li > ul')
#print(shengshi)
print(len(names))
print(len(shengshi))


dict = {'hospital_name': 'None' ,'hospital_rank':'None ','hospital_property':'None'};
list=[]
#print(dict)
#print(list)



for i in range(len(names)):
    name = names[i].find_parent('b').get_text()
    #print(name)
    dict['hospital_name'] = name
    #print(dict['hospital_name'])
    info = shengshi[i].select('li')
    for li in info:
        if li.b:
            title = li.b.get_text()
            if title == "医院等级":
                value = li.contents[1].replace('：', '')
                #print(title,":",value)
                dict['hospital_rank'] = value
                #print(dict['hospital_rank'])
            elif title == "经营方式":
                value2 = li.contents[1].replace('：', '')
                #print(title,":",value2)
                dict['hospital_property'] = value2
                #print(dict['hospital_property'])
    #print(dict)
    list.append(dict);
    #dict={}
    dict = {'hospital_name': 'None' ,'hospital_rank':'None ','hospital_property':'None'};
    

    
#print(list)

# %%
#存储海南省的市县代码 保存为：海南省.xls
#最新版本代码测试海南省
####################################海南省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 
#18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字


re_list=[]

for re in range(320,339):
    str2 = L_city[re]
    str=str1+str2+str3
    #print(str)
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    county = soup_city.find('ul')
    #print(county.get_text())
    a_list = county.select('a')
    
    
    
    #print(len(a_list))
    #print(a_list[0].get_text())
    if(a_list[0].get_text() == '登录／创建账户'):
        re_list.append(re)
        #print(re_list)

id=0        
for new_re in range(320,339):
    if (new_re == re_list[id]):
        id=id+1
        new_str= str1 + '海南省'+ L_city[new_re] + str3
        html_city = requests.get(new_str).text
        soup_city = BeautifulSoup(html_city, 'lxml')
        county = soup_city.find('ul')
        #print(county.get_text())
        a_list = county.select('a')
    else:
        str2 = L_city[new_re]
        str=str1+str2+str3
        #print(str)
        html_city = requests.get(str).text
        soup_city = BeautifulSoup(html_city, 'lxml')
        county = soup_city.find('ul')
        #print(county.get_text())
        a_list = county.select('a')
    
    eachcity_county = []
    eachcity_county.append(L_city[new_re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

#也去除页面不存在的情况
for info in range(len(county_info)):
    if (county_info[info][1] == '登录／创建'):
        del county_info[info][1]
        
    #去除甲乙丙丁错误  
    elif ((county_info[info][1] == '一甲') or (county_info[info][1] == '一乙') or (county_info[info][1] == '一丙') 
        or (county_info[info][1] == '二甲') or (county_info[info][1] == '二乙') or (county_info[info][1] == '二丙') 
        or (county_info[info][1] == '三甲') 
        or (county_info[info][1] == '三乙') 
        or (county_info[info][1] == '三丙')):
            del county_info[info][1:] 
        #for del_co in range(len(county_info[info])):
            #del county_info

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[5])
print(county_info[16])
print(county_info[17])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('海南省.xls')
