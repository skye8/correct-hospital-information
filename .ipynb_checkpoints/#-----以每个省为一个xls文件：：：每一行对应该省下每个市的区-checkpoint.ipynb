# %%
# -*- coding:utf-8 -*-
import requests
from bs4 import BeautifulSoup

url = 'http://www.a-hospital.com/w/全国医院列表'
html = requests.get(url).text
soup = BeautifulSoup(html, 'lxml')

provinces = soup.select('div > h3')
#print(names[:-3])
print("全部省的个数（含4个直辖市）：")
print(len(provinces[:-3]))

#每个省对应的医院个数
count_city=[]

L=[]

for eachprovince in provinces[:-3]:
    all_province_hospital = eachprovince.next_sibling.next_sibling
    #print(all_province_hospital.get_text())
    
    #存储在List列表
    list=[]
    list.append(all_province_hospital.get_text()[:-4])
    
    city = all_province_hospital.next_sibling.next_sibling
    cities = city.find_all('a')
    #print(all_province_hospital.get_text()[:-4] +"对应市的个数：")
    #print(len(cities))
    count_city.append(len(cities))
    for j in range(len(cities)):
        #print(cities[j].get_text())
        temp = cities[j].get_text()
        list.append(temp)
    
    #每个省作为一个List，然后全部省存在L
    L.append(list)
    #print('\n')

#print(L)
print(count_city)


#以下是 省市  的列表形式

#[['北京市医院列表', '朝阳区', '海淀区', '丰台区', '东城区', '西城区', '昌平区', '宣武区', '房山区', '崇文区', '石景山区',
#'门头沟区', '通州区', '大兴区', '顺义区', '怀柔区', '密云县', '平谷区', '延庆县'], 

#['上海市医院列表', '浦东新区', '徐汇区', '长宁区', '闸北区', '虹口区', '杨浦区', '闵行区', '宝山区', '黄浦区', '奉贤区', 
#'静安区', '卢湾区', '普陀区', '崇明县', '青浦区', '嘉定区', '金山区', '松江区'], 

#['重庆市医院列表', '九龙坡区', '万州区', '沙坪坝区', '渝中区', '江北区', '南岸区', '巴南区', '永川市', '江津市', '綦江县',
#'北碚区', '合川市', '南川市', '涪陵区', '渝北区', '大渡口区', '大足县', '长寿区', '荣昌县', '梁平县', '云阳县', '璧山县',
#'开县', '万盛区', '潼南县', '垫江县', '丰都县', '巫溪县', '奉节县', '铜梁县', '忠县', '黔江区', '巫山县',
#'酉阳土家族苗族自治县', '武隆县', '城口县', '彭水苗族土家族自治县', '秀山土家族苗族自治县', '双桥区', '石柱土家族自治县'],
# Out:
# 全部省的个数（含4个直辖市）：
# 31
# [18, 18, 40, 18, 13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7]

# %%
#模板----

# %%
#接下来是获取对应  市   下面的  区   （去除几个直辖市的：北京、上海、重庆、天津）
#共31个，，去除前4个直辖市，从第4开始
str1='http://www.a-hospital.com/w/'
str3='医院列表'

#####存储了所有市     如下格式（对应上述省的顺序）
#['苏州市', '无锡市', '淮安市', '南京市', '盐城市', '徐州市', '宿迁市', '泰州市', 
#'南通市', '常州市', '连云港市', '扬州市', '镇江市', '广州市', '深圳市', '惠州市',
# '佛山市', '梅州市', '肇庆市', '韶关市', '揭阳市', '汕头市', '东莞市', '湛江市', 
#'中山市', '清远市', '潮州市', '茂名市', '珠海市', '江门市', '阳江市',

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)


print(len(L_city))
#for k in range(len(L_city)):





str1='http://www.a-hospital.com/w/'
str3='医院列表'

county_info = []
#############################################################获取每个市下的  区


#江苏省、广东省、山东省。。。。。。。。。。。。（每一个省的城市数）
#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7
#for re in range(len(L_city)):
for re in range(5):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[3])
print(county_info[4])


#print(county_info[len(L_city)])
#print(county_info[len(L_city)-2])

# %%
#江苏省进行实验

# %%
#接下来是获取对应  市   下面的  区   （去除几个直辖市的：北京、上海、重庆、天津）
#共31个，，去除前4个直辖市，从第4开始
str1='http://www.a-hospital.com/w/'
str3='医院列表'

#####存储了所有市     如下格式（对应上述省的顺序）
#['苏州市', '无锡市', '淮安市', '南京市', '盐城市', '徐州市', '宿迁市', '泰州市', 
#'南通市', '常州市', '连云港市', '扬州市', '镇江市', '广州市', '深圳市', '惠州市',
# '佛山市', '梅州市', '肇庆市', '韶关市', '揭阳市', '汕头市', '东莞市', '湛江市', 
#'中山市', '清远市', '潮州市', '茂名市', '珠海市', '江门市', '阳江市',

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)


print(len(L_city))
#for k in range(len(L_city)):





str1='http://www.a-hospital.com/w/'
str3='医院列表'

county_info = []
#############################################################获取每个市下的  区


#江苏省、广东省、山东省。。。。。。。。。。。。（每一个省的城市数）
#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7
#for re in range(len(L_city)):

###13个市，L_city中的顺序为（0到12）
for re in range(13):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[11])
print(county_info[12])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('江苏省.xls')
# Out:
# 358
# ['苏州市', '金阊区', '沧浪区', '平江区', '虎丘区', '吴中区', '相城区', '吴江市', '昆山市', '太仓市', '常熟市', '张家港市']
# ['无锡市', '崇安区', '南长区', '北塘区', '滨湖区', '惠山区', '锡山区', '江阴市', '宜兴市']
# ['淮安市', '清河区', '清浦区', '楚州区', '淮阴区', '金湖县', '盱眙县', '洪泽县', '涟水县']
# ['扬州市', '广陵区', '维扬区', '邗江区', '仪征市', '江都市', '高邮市', '宝应县']
# ['镇江市', '京口区', '润州区', '丹徒区', '扬中市', '丹阳市', '句容市']

# %%
####################################广东省


str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 
#21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(13,34):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[11])
print(county_info[12])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('广东省.xls')
# Out:
# 358
# ['广州市', '越秀区', '荔湾区', '海珠区', '天河区', '白云区', '黄埔区', '番禺区', '花都区', '增城', '从化', '萝岗区', '南沙区']
# ['深圳市', '福田区', '罗湖区', '南山区', '宝安区', '龙岗区', '盐田区']
# ['惠州市', '惠城', '惠阳', '博罗', '惠东', '龙门']
# ['中山市', '石岐区', '东区', '西区', '南区', '五桂山', '小榄', '古镇', '横栏', '东升', '港口', '沙溪', '大涌', '黄圃', '南头', '东凤', '阜沙', '三角', '民众', '南朗', '三乡', '坦洲', '板芙', '神湾', '火炬开发区']
# ['清远市', '清城', '英德', '连州', '佛冈', '阳山', '清新', '连山壮族瑶族', '连南瑶族']

# %%
####################################山东省


str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 
#17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(34,51):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[15])
print(county_info[16])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('山东省.xls')
# Out:
# 358
# ['青岛市', '市南区', '市北区', '四方区', '黄岛区', '崂山区', '城阳区', '李沧区', '胶州市', '即墨市', '平度市', '胶南市', '莱西市']
# ['济南市', '市中区', '历下区', '槐荫区', '天桥区', '历城区', '长清区', '章丘市', '平阴县', '济阳县', '商河县']
# ['济宁市', '市中区', '任城区', '曲阜市', '兖州市', '邹城市', '微山县', '鱼台县', '金乡县', '嘉祥县', '汶上县', '泗水县', '梁山县']
# ['日照市', '东港区', '五莲县', '莒县']
# ['莱芜市', '莱城区', '钢城区']

# %%
####################################辽宁省


str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 
#14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(51,65):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[12])
print(county_info[13])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('辽宁省.xls')
# Out:
# 358
# ['沈阳市', '沈河区', '和平区', '大东区', '皇姑区', '铁西区', '苏家屯区', '东陵区', '新城子区', '于洪区', '新民市', '辽中县', '康平县', '法库县']
# ['大连市', '西岗区', '中山区', '沙河口区', '甘井子区', '旅顺口区', '金州区', '瓦房店市', '普兰店市', '庄河市', '长海县']
# ['锦州市', '太和区', '古塔区', '凌河区', '凌海市', '北宁市', '黑山县', '义县']
# ['本溪市', '平山区', '溪湖区', '明山区', '南芬区', '本溪满族自治县', '桓仁满族自治县']
# ['盘锦市', '双台子区', '兴隆台区', '大洼县', '盘山县']

# %%
####################################河北省


str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 
#11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(65,76):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[9])
print(county_info[10])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('河北省.xls')
# Out:
# 358
# ['石家庄市', '长安市', '桥东区', '桥西区', '新华区', '裕华县', '井陉矿区', '辛集县', '藁城县', '晋州县', '新乐县', '鹿泉县', '井陉县', '正定县', '栾城县', '行唐县', '灵寿县', '高邑县', '深泽县', '赞皇县', '无极县', '平山县', '元氏县', '赵县']
# ['唐山市', '路北县', '路南县', '古冶县', '开平县', '丰南县', '丰润区', '遵化市', '迁安市', '滦 县', '滦南县', '乐亭县', '迁西县', '玉田县', '唐海县']
# ['保定市', '新市镇', '北市', '南市', '定州市', '涿州市', '安国市', '高碑店市', '满城县', '清苑县', '易县', '徐水县', '涞源县', '定兴县', '顺平县', '唐县', '望都县', '涞水县', '高阳县', '安新县', '雄县', '容城县', '曲阳县', '阜平县', '博野县', '蠡县']
# ['衡水市', '桃城区', '冀州市', '深州市', '枣强县', '武邑县', '武强县', '饶阳县', '安平县', '故城县', '景 县', '阜城县']
# ['秦皇岛市', '海港区', '山海关区', '北戴河区', '昌黎县', '抚宁县', '卢龙县', '青龙满族自治县']

# %%
####################################河南省


str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 
#18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(76,94):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[16])
print(county_info[17])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('河南省.xls')
# Out:
# 358
# ['郑州市', '中原区', '二七区', '管城回族区', '金水区', '上街区', '邙山区', '新郑市', '登封市', '新密市', '巩义市', '荥阳市', '中牟县']
# ['洛阳市', '西工区', '老城区', '瀍河回族区', '涧西区', '吉利区', '洛龙区', '偃师市', '孟津县', '新安县', '栾川县', '嵩县', '汝阳县', '宜阳县', '洛宁县', '伊川县']
# ['南阳市', '卧龙区', '宛城区', '邓州市', '南召县', '方城县', '西峡县', '镇平县', '内乡县', '淅川县', '社旗县', '唐河县', '新野县', '桐柏县']
# ['鹤壁市', '淇滨区', '山城区', '鹤山区', '浚县', '淇县']
# ['济源市', '三甲', '三乙', '三丙', '二甲', '二乙', '二丙', '一甲', '一乙', '一丙']

# %%
####################################四川省


str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 
#21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(94,115):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[19])
print(county_info[20])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('四川省.xls')
# Out:
# 358
# ['成都市', '青羊区', '锦江区', '金牛区', '武侯区', '成华区', '龙泉驿区', '青白江区', '新都区', '温江区', '崇州市', '邛崃市', '都江堰市', '金堂县', '双流县', '郫县', '大邑县', '蒲江县', '新津县']
# ['绵阳市', '涪城区', '游仙区', '江油市', '三台县', '盐亭县', '安县', '梓潼县', '北川县', '平武县']
# ['乐山市', '市中区', '沙湾区', '五通桥区', '金口河区', '峨眉山市', '犍为县', '井研县', '夹江县', '沐川县', '峨边彝族自治县', '马边彝族自治县']
# ['广安市', '广安区', '华蓥市', '岳池县', '武胜县', '邻水县']
# ['眉山市', '东坡区', '仁寿县', '彭山县', '洪雅县', '丹棱县', '青神县']

# %%
####################################黑龙江省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 
#13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(115,128):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[11])
print(county_info[12])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('黑龙江省.xls')
# Out:
# 358
# ['哈尔滨市', '道里区', '南岗区', '道外区', '香坊区', '平房区', '双城市', '尚志市', '五常市', '阿城市', '呼兰区', '依兰县', '方正县', '宾县', '巴彦县', '木兰县', '通河县', '延寿县', '松北区']
# ['齐齐哈尔市', '龙沙区', '建华区', '铁峰区', '昂昂溪区', '富拉尔基区', '碾子山区', '梅里斯达斡尔区', '讷河市', '龙江县', '依安县', '泰来县', '甘南县', '富裕县', '克山县', '克东县', '拜泉县']
# ['牡丹江市', '爱民区', '东安区', '阳明区', '西安区', '穆棱市', '绥芬河市', '海林市', '宁安市', '东宁县', '林口县']
# ['大兴安岭地区', '登录／创建']
# ['七台河市', '桃山区', '新兴区', '茄子河区', '勃利县']

# %%
####################################山西省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 
#11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(128,139):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[9])
print(county_info[10])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('山西省.xls')
# Out:
# 358
# ['太原市', '杏花岭区', '小店区', '迎泽区', '尖草坪区', '万柏林区', '晋源区', '古交市', '清徐县', '阳曲县', '娄烦县']
# ['运城市', '盐湖区', '永济市', '河津市', '芮城县', '临猗县', '万荣县', '新绛县', '稷山县', '闻喜县', '夏 县', '绛 县', '平陆县', '垣曲县']
# ['临汾市', '尧都区', '侯马市', '霍州市', '曲沃县', '翼城县', '襄汾县', '洪洞县', '古 县', '安泽县', '浮山县', '吉 县', '乡宁县', '蒲 县', '大宁县', '永和县', '隰 县', '汾西县']
# ['阳泉市', '城 区', '矿 区', '郊 区', '平定县', '盂 县']
# ['朔州市', '朔城区', '平鲁区', '山阴县', '应 县', '右玉县', '怀仁县']

# %%
####################################湖北省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 
#17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(139,156):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[15])
print(county_info[16])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('湖北省.xls')
# Out:
# 358
# ['武汉市', '江岸区', '江汉区', '硚口区', '汉阳区', '武昌区', '青山区', '洪山区', '东西湖区', '汉南区', '蔡甸区', '江夏区', '黄陂区', '新洲区']
# ['襄樊市', '襄城区', '樊城区', '襄阳区', '老河口市', '枣阳市', '宜城市', '南漳县', '谷城县', '保康县']
# ['宜昌市', '西陵区', '伍家岗区', '点军区', '猇亭区', '夷陵区', '枝江市', '宜都市', '当阳市', '远安县', '兴山县', '秭归县', '长阳土家族自治县', '五峰土家族自治县']
# ['潜江市', '三甲', '三乙', '三丙', '二甲', '二乙', '二丙', '一甲', '一乙', '一丙']
# ['神农架林区', '登录／创建']

# %%
####################################湖南省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 
#14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(156,170):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[12])
print(county_info[13])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('湖南省.xls')
# Out:
# 358
# ['长沙市', '岳麓区', '芙蓉区', '天心区', '开福区', '雨花区', '浏阳市', '长沙县', '望城县', '宁乡县']
# ['衡阳市', '雁峰区', '珠晖区', '石鼓区', '蒸湘区', '南岳区', '常宁市', '耒阳市', '衡阳县', '衡南县', '衡山县', '衡东县', '祁东县']
# ['湘潭市', '雨湖区', '岳塘区', '湘乡市', '韶山市', '湘潭县']
# ['湘西土家族苗族自治州', '吉首市', '泸溪县', '凤凰县', '花垣县', '保靖县', '古丈县', '永顺县', '龙山县']
# ['张家界市', '永定区', '武陵源区', '慈利县', '桑植县']

# %%
####################################陕西省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 
#10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(170,180):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[8])
print(county_info[9])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('陕西省.xls')
# Out:
# 358
# ['西安市', '莲湖区', '新城区', '碑林区', '灞桥区', '未央区', '雁塔区', '阎良区', '临潼区', '长安区', '蓝田县', '周至县', '户县', '高陵县']
# ['渭南市', '临渭区', '华阴市', '韩城市', '华县', '潼关县', '大荔县', '蒲城县', '澄城县', '白水县', '合阳县', '富平县']
# ['咸阳市', '秦都区', '杨凌区', '渭城区', '兴平市', '三原县', '泾阳县', '乾县', '礼泉县', '永寿县', '彬县', '长武县', '旬邑县', '淳化县', '武功县']
# ['商洛市', '商州区', '洛南县', '丹凤县', '商南县', '山阳县', '镇安县', '柞水县']
# ['铜川市', '王益区', '印台区', '耀州区', '宜君县']

# %%
####################################浙江省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 
#11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(180,191):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[9])
print(county_info[10])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('浙江省.xls')
# Out:
# 358
# ['杭州市', '拱墅区', '上城区', '下城区', '江干区', '西湖区', '滨江区', '余杭区', '萧山区', '临安市', '富阳市', '建德市', '桐庐县', '淳安县']
# ['宁波市', '海曙区', '江东区', '江北区', '镇海区', '北仑区', '鄞州区', '余姚市', '慈溪市', '奉化市', '宁海县', '象山县']
# ['温州市', '鹿城区', '龙湾区', '瓯海区', '瑞安市', '乐清市', '永嘉县', '文成县', '平阳县', '泰顺县', '洞头县', '苍南县']
# ['湖州市', '长兴县', '德清县', '安吉县', '吴兴区', '南浔区']
# ['舟山市', '定海区', '普陀区', '岱山县', '嵊泗县']

# %%
####################################云南省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 
#16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(191,207):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[14])
print(county_info[15])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('云南省.xls')
# Out:
# 358
# ['昆明市', '盘龙区', '五华区', '官渡区', '西山区', '东川区', '安宁市', '呈贡县', '晋宁县', '富民县', '宜良县', '嵩明县', '石林彝族自治县', '禄劝彝族苗族自治县', '寻甸回族彝族自治县']
# ['红河哈尼族彝族自治州', '个旧市', '开远市', '蒙自县', '绿春县', '建水县', '石屏县', '弥勒县', '泸西县', '元阳县', '红河县', '金平苗族瑶族傣族自治县', '河口瑶族自治县', '屏边苗族自治县']
# ['大理白族自治州', '大理市', '祥云县', '宾川县', '弥渡县', '永平县', '云龙县', '洱源县', '剑川县', '鹤庆县', '漾濞彝族自治县', '南涧彝族自治县', '巍山彝族回族自治县']
# ['怒江傈僳族自治州', '泸水县', '福贡县', '贡山独龙族怒族自治县', '兰坪白族普米族自治县']
# ['迪庆藏族自治州', '香格里拉县', '德钦县', '维西傈僳族自治县']

# %%
####################################吉林省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 
#9, 17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(207,216):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[7])
print(county_info[8])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('吉林省.xls')
# Out:
# 358
# ['长春市', '朝阳区', '南关区', '宽城区', '二道区', '绿园区', '双阳区', '德惠市', '九台市', '榆树市', '农安县']
# ['延边朝鲜族自治州', '延吉市', '图们市', '敦化市', '珲春市', '龙井市', '和龙市', '汪清县', '安图县']
# ['吉林市', '船营区', '龙潭区', '昌邑区', '丰满区', '磐石市', '蛟河市', '桦甸市', '舒兰市', '永吉县']
# ['白山市', '八道江区', '临江市', '江源县', '抚松县', '靖宇县', '长白朝鲜族自治县']
# ['松原市', '宁江区', '扶余县', '长岭县', '乾安县', '前郭尔罗斯蒙古族自治县']

# %%
####################################安徽省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 
#17, 14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(216,233):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[15])
print(county_info[16])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('安徽省.xls')
# Out:
# 358
# ['合肥市', '瑶海区', '庐阳区', '蜀山区', '包河区', '长丰县', '肥东县', '肥西县']
# ['淮南市', '田家庵区', '大通区', '谢家集区', '八公山区', '潘集区', '凤台县']
# ['安庆市', '迎江区', '大观区', '郊区', '桐城市', '怀宁县', '枞阳县', '潜山县', '太湖县', '宿松县', '望江县', '岳西县']
# ['亳州市', '谯城区', '涡阳县', '蒙城县', '利辛县']
# ['池州市', '贵池区', '东至县', '石台县', '青阳县']

# %%
####################################广西壮族自治区

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 
#14, 11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(233,247):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[12])
print(county_info[13])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('广西壮族自治区.xls')
# Out:
# 358
# ['南宁市', '兴宁区', '江南区', '青秀区', '西乡塘区', '邕宁区', '良庆区', '武鸣县', '横县', '宾阳县', '上林县', '隆安县', '马山县']
# ['柳州市', '城中区', '鱼峰区', '柳南区', '柳北区', '柳江县', '柳城县', '鹿寨县', '融安县', '融水苗族自治县', '三江侗族自治县']
# ['桂林市', '秀峰区', '叠彩区', '象山区', '七星区', '雁山区', '阳朔县', '临桂县', '灵川县', '全州县', '兴安县', '永福县', '灌阳县', '资源县', '平乐县', '荔浦县', '龙胜各族自治县', '恭城瑶族自治县']
# ['贺州市', '八步区', '昭平县', '钟山县', '富川瑶族自治县']
# ['防城港市', '港口区', '防城区', '东兴市', '上思县']

# %%
####################################江西省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 
#11, 9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(247,258):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[9])
print(county_info[10])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('江西省.xls')
# Out:
# 358
# ['南昌市', '东湖区', '西湖区', '青云谱区', '湾里区', '青山湖区', '南昌县', '新建县', '安义县', '进贤县']
# ['赣州市', '章贡区', '瑞金市', '南康区', '赣县', '信丰县', '大余县', '上犹县', '崇义县', '安远县', '龙南县', '定南县', '全南县', '宁都县', '于都县', '兴国县', '会昌县', '寻乌县', '石城县']
# ['上饶市', '信州区', '德兴市', '上饶县', '广丰县', '玉山县', '铅山县', '横峰县', '弋阳县', '余干县', '波阳县', '万年县', '婺源县']
# ['鹰潭市', '月湖区', '贵溪市', '余江县']
# ['新余市', '渝水区', '分宜县']

# %%
####################################福建省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 
#9, 18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(258,267):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[7])
print(county_info[8])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('福建省.xls')
# Out:
# 358
# ['福州市', '鼓楼区', '台江区', '仓山区', '马尾区', '晋安区', '福清市', '长乐市', '闽侯县', '连江县', '罗源县', '闽清县', '永泰县', '平潭县']
# ['泉州市', '鲤城区', '丰泽区', '洛江区', '泉港区', '石狮市', '晋江市', '南安市', '惠安县', '安溪县', '永春县', '德化县', '金门县']
# ['南平市', '延平区', '邵武市', '武夷山市', '建瓯市', '建阳市', '顺昌县', '浦城县', '光泽县', '松溪县', '政和县']
# ['莆田市', '城厢区', '涵江区', '荔城区', '秀屿区', '仙游县']
# ['宁德市', '蕉城区', '福安市', '福鼎市', '寿宁县', '霞浦县', '柘荣县', '屏南县', '古田县', '周宁县']

# %%
####################################新疆维吾尔自治区

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 
#18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(267,285):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[16])
print(county_info[17])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('新疆维吾尔自治区.xls')
# Out:
# 358
# ['乌鲁木齐市', '天山区', '沙依巴克区', '新市区', '水磨沟区', '头屯河区', '达坂城区', '东山区', '乌鲁木齐县']
# ['喀什地区', '登录／创建']
# ['伊犁哈萨克自治州', '奎屯市', '伊宁县', '霍城县', '巩留县', '新源县', '昭苏县', '特克斯县', '伊宁市', '尼勒克县', '察布查尔锡伯自治县']
# ['图木舒克市', '登录／创建']
# ['五家渠市', '登录／创建']

# %%
####################################内蒙古自治区

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 
#12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(285,297):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[10])
print(county_info[11])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('内蒙古自治区.xls')
# Out:
# 358
# ['呼和浩特市', '回民区', '新城区', '玉泉区', '赛罕区', '托克托县', '武川县', '和林格尔县', '清水河县', '土默特左旗']
# ['呼伦贝尔市', '海拉尔区', '满洲里市', '扎兰屯市', '牙克石市', '根河市', '额尔古纳市', '阿荣旗', '新巴尔虎右旗', '新巴尔虎左旗', '陈巴尔虎旗', '鄂伦春自治旗', '鄂温克族自治旗', '莫力达瓦达斡尔族自治旗']
# ['赤峰市', '红山区', '元宝山区', '松山区', '宁城县', '林西县', '阿鲁科尔沁旗', '巴林左旗', '巴林右旗', '克什克腾旗', '翁牛特旗', '喀喇沁旗', '敖汉旗']
# ['阿拉善盟', '阿拉善左旗', '阿拉善右旗', '额济纳旗']
# ['包头市', '登录／创建']

# %%
####################################甘肃省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 
#14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(297,311):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[12])
print(county_info[13])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('甘肃省.xls')
# Out:
# 358
# ['兰州市', '城关区', '七里河区', '西固区', '安宁区', '红古区', '永登县', '皋兰县', '榆中县']
# ['天水市', '秦城区', '北道区', '清水县', '秦安县', '甘谷县', '武山县', '张家川回族自治县']
# ['陇南地区', '登录／创建']
# ['金昌市', '金川区', '永昌县']
# ['嘉峪关市', '三甲', '三乙', '三丙', '二甲', '二乙', '二丙', '一甲', '一乙', '一丙']

# %%
####################################贵州省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 
#9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(311,320):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[7])
print(county_info[8])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('贵州省.xls')
# Out:
# 358
# ['贵阳市', '南明区', '云岩区', '花溪区', '乌当区', '白云区', '小河区', '清镇市', '开阳县', '修文县', '息烽县']
# ['遵义市', '红花岗区', '赤水市', '仁怀市', '遵义县', '桐梓县', '绥阳县', '正安县', '凤冈县', '湄潭县', '余庆县', '习水县', '道真仡佬族苗族自治县', '务川仡佬族苗族自治县']
# ['毕节地区', '登录／创建']
# ['铜仁地区', '登录／创建']
# ['黔西南布依族苗族自治州', '兴义市', '兴仁县', '普安县', '晴隆县', '贞丰县', '望谟县', '册亨县', '安龙县']

# %%
####################################海南省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 、
#19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(320,339):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[17])
print(county_info[18])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('海南省.xls')
# Out:
# 358
# ['海口市', '秀英区', '龙华区', '琼山区', '美兰区']
# ['儋州市', '三甲', '三乙', '三丙', '二甲', '二乙', '二丙', '一甲', '一乙', '一丙']
# ['三亚市', '三甲', '三乙', '三丙', '二甲', '二乙', '二丙', '一甲', '一乙', '一丙']
# ['陵水黎族自治县', '登录／创建']
# ['琼山市', '登录／创建']

# %%
####################################青海省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 、19, 
#8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(339,347):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[6])
print(county_info[7])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('青海省.xls')
# Out:
# 358
# ['西宁市', '城中区', '城东区', '城西区', '城北区', '大通回族土族自治县', '湟源县', '湟中县']
# ['海西蒙古族藏族自治州', '德令哈市', '格尔木市', '乌兰县', '都兰县', '天峻县']
# ['海东地区', '登录／创建']
# ['海南藏族自治州', '共和县', '同德县', '贵德县', '兴海县', '贵南县']
# ['海北藏族自治州', '海晏县', '祁连县', '刚察县', '门源回族自治县']

# %%
####################################宁夏回族自治区

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 、19, 8, 
#4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(347,351):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    #county = soup_city.find('ul')
    #print(county.get_text())

    county = soup_city.find('ul')
    a_list = county.select('a')
    #print(len(a_list))
    #print(a_list[1].get_text())

    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[3])



import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('宁夏回族自治区.xls')
# Out:
# 358
# ['银川市', '西夏区', '金凤区', '兴庆区', '灵武市', '永宁县', '贺兰县']
# ['吴忠市', '利通区', '青铜峡市', '中卫县', '中宁县', '盐池县', '同心县']
# ['固原市', '原州区', '海原县', '西吉县', '隆德县', '泾源县', '彭阳县']

# %%
####################################西藏自治区

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 、19, 8, 4, 
#7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字
for re in range(351,358):
    str2 = L_city[re]
    str=str1+str2+str3
    
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    county = soup_city.find('ul')
    #print(county.get_text())
    a_list = county.select('a')
    #print(len(a_list))



    eachcity_county = []
    eachcity_county.append(L_city[re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[6])



import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('西藏自治区.xls')
# Out:
# 358
# ['日喀则地区', '登录／创建']
# ['那曲地区', '登录／创建']
# ['拉萨市', '城关区', '林周县', '当雄县', '尼木县', '曲水县', '堆龙德庆县', '达孜县', '墨竹工卡县']
# ['林芝地区', '登录／创建']

# %%
##############n#######使用最后一个西藏自治区进行测试（如何获得全部正确的省市）

# %%
####################################西藏自治区

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 18, 12, 14, 9, 、19, 8, 4, 
#7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字

re_list=[]

for re in range(351,358):
    str2 = L_city[re]
    str=str1+str2+str3
    #print(str)
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    county = soup_city.find('ul')
    #print(county.get_text())
    a_list = county.select('a')
    
    
    
    #print(len(a_list))
    #print(a_list[0].get_text())
    if(a_list[0].get_text() == '登录／创建账户'):
        re_list.append(re)
        #print(re_list)
        
id=0        
for new_re in range(351,358):
    if (new_re == re_list[id]):
        id=id+1
        new_str= str1 + '西藏自治区'+ L_city[new_re] + str3
        html_city = requests.get(new_str).text
        soup_city = BeautifulSoup(html_city, 'lxml')
        county = soup_city.find('ul')
        #print(county.get_text())
        a_list = county.select('a')
    else:
        str2 = L_city[new_re]
        str=str1+str2+str3
        #print(str)
        html_city = requests.get(str).text
        soup_city = BeautifulSoup(html_city, 'lxml')
        county = soup_city.find('ul')
        #print(county.get_text())
        a_list = county.select('a')
    
    eachcity_county = []
    eachcity_county.append(L_city[new_re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)
    



print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[6])



import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('西藏自治区.xls')
# Out:
# 358
# ['日喀则地区', '日喀则市', '南木林县', '江孜县', '定日县', '萨迦县', '拉孜县', '昂仁县', '谢通门县', '白朗县', '仁布县', '康马县', '定结县', '仲巴县', '亚东县', '吉隆县', '聂拉木县', '萨嘎县', '岗巴县']
# ['那曲地区', '那曲县', '嘉黎县', '比如县', '聂荣县', '安多县', '申扎县', '索县', '班戈县', '巴青县', '尼玛县']
# ['拉萨市', '城关区', '林周县', '当雄县', '尼木县', '曲水县', '堆龙德庆县', '达孜县', '墨竹工卡县']
# ['林芝地区', '林芝县', '工布江达县', '米林县', '墨脱县', '波密县', '察隅县', '朗县']

# %% [markdown]
# # 测试新疆维吾尔自治区     去除了3种错误
# 1.去除（ 创建/添加账户 ）错误
# 2.去除甲乙丙丁错误
# 3.也去除页面不存在的情况

# %%
####################################新疆维吾尔自治区

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 
#18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字


re_list=[]

for re in range(267,285):
    str2 = L_city[re]
    str=str1+str2+str3
    #print(str)
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    county = soup_city.find('ul')
    #print(county.get_text())
    a_list = county.select('a')
    
    
    
    #print(len(a_list))
    #print(a_list[0].get_text())
    if(a_list[0].get_text() == '登录／创建账户'):
        re_list.append(re)
        #print(re_list)

id=0        
for new_re in range(267,285):
    if (new_re == re_list[id]):
        id=id+1
        new_str= str1 + '新疆维吾尔自治区'+ L_city[new_re] + str3
        html_city = requests.get(new_str).text
        soup_city = BeautifulSoup(html_city, 'lxml')
        county = soup_city.find('ul')
        #print(county.get_text())
        a_list = county.select('a')
    else:
        str2 = L_city[new_re]
        str=str1+str2+str3
        #print(str)
        html_city = requests.get(str).text
        soup_city = BeautifulSoup(html_city, 'lxml')
        county = soup_city.find('ul')
        #print(county.get_text())
        a_list = county.select('a')
    
    eachcity_county = []
    eachcity_county.append(L_city[new_re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

#也去除页面不存在的情况
for info in range(len(county_info)):
    if (county_info[info][1] == '登录／创建'):
        del county_info[info][1]
        
    #去除甲乙丙丁错误  
    elif ((county_info[info][1] == '一甲') or (county_info[info][1] == '一乙') or (county_info[info][1] == '一丙') 
        or (county_info[info][1] == '二甲') or (county_info[info][1] == '二乙') or (county_info[info][1] == '二丙') 
        or (county_info[info][1] == '三甲') 
        or (county_info[info][1] == '三乙') 
        or (county_info[info][1] == '三丙')):
            del county_info[info][1:] 
        #for del_co in range(len(county_info[info])):
            #del county_info

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[5])
print(county_info[16])
print(county_info[17])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('新疆维吾尔自治区.xls')
# Out:
# 358
# ['乌鲁木齐市', '天山区', '沙依巴克区', '新市区', '水磨沟区', '头屯河区', '达坂城区', '东山区', '乌鲁木齐县']
# ['喀什地区', '喀什市', '疏附县', '疏勒县', '英吉沙县', '泽普县', '莎车县', '叶城县', '麦盖提县', '岳普湖县', '伽师县', '巴楚县', '塔什库尔干塔吉克自治县']
# ['伊犁哈萨克自治州', '奎屯市', '伊宁县', '霍城县', '巩留县', '新源县', '昭苏县', '特克斯县', '伊宁市', '尼勒克县', '察布查尔锡伯自治县']
# ['石河子市']
# ['图木舒克市']
# ['五家渠市']

# %%
#最新版本代码测试海南省
####################################海南省

str1='http://www.a-hospital.com/w/'
str3='医院列表'

L_city=[]
###（4,31）存储除了前四个直辖市后面的省
#存储 所有市的列表    其中该列表中的每一项包括：：一个市名，，该市下所有的区
for i in range(4,31):
    for j in range(1,len(L[i])):
        #print(L[i][j])
        L_city.append(L[i][j])  
    #print('\n')   
#print(L_city)
print(len(L_city))


str1='http://www.a-hospital.com/w/'
str3='医院列表'
county_info = []
#############################################################获取每个市下的  区

#13, 21, 17, 14, 11, 18, 21, 13, 11, 17, 14, 10, 11, 16, 9, 17, 14, 11, 9, 
#18, 12, 14, 9, 19, 8, 4, 7

###13个市，L_city中的顺序为（0到12） 起始数字：上一次的range()末尾数           起始数字+（个数） = range末尾数字


re_list=[]

for re in range(320,339):
    str2 = L_city[re]
    str=str1+str2+str3
    #print(str)
    html_city = requests.get(str).text
    soup_city = BeautifulSoup(html_city, 'lxml')
    county = soup_city.find('ul')
    #print(county.get_text())
    a_list = county.select('a')
    
    
    
    #print(len(a_list))
    #print(a_list[0].get_text())
    if(a_list[0].get_text() == '登录／创建账户'):
        re_list.append(re)
        #print(re_list)

id=0        
for new_re in range(320,339):
    if (new_re == re_list[id]):
        id=id+1
        new_str= str1 + '海南省'+ L_city[new_re] + str3
        html_city = requests.get(new_str).text
        soup_city = BeautifulSoup(html_city, 'lxml')
        county = soup_city.find('ul')
        #print(county.get_text())
        a_list = county.select('a')
    else:
        str2 = L_city[new_re]
        str=str1+str2+str3
        #print(str)
        html_city = requests.get(str).text
        soup_city = BeautifulSoup(html_city, 'lxml')
        county = soup_city.find('ul')
        #print(county.get_text())
        a_list = county.select('a')
    
    eachcity_county = []
    eachcity_county.append(L_city[new_re])
    for u in range(len(a_list)):
        eachcity_county.append(a_list[u].get_text()[:-2])

    #print(eachcity_county)
    county_info.append(eachcity_county)

#也去除页面不存在的情况
for info in range(len(county_info)):
    if (county_info[info][1] == '登录／创建'):
        del county_info[info][1]
        
    #去除甲乙丙丁错误  
    elif ((county_info[info][1] == '一甲') or (county_info[info][1] == '一乙') or (county_info[info][1] == '一丙') 
        or (county_info[info][1] == '二甲') or (county_info[info][1] == '二乙') or (county_info[info][1] == '二丙') 
        or (county_info[info][1] == '三甲') 
        or (county_info[info][1] == '三乙') 
        or (county_info[info][1] == '三丙')):
            del county_info[info][1:] 
        #for del_co in range(len(county_info[info])):
            #del county_info

print(county_info[0])
print(county_info[1])
print(county_info[2])
print(county_info[5])
print(county_info[16])
print(county_info[17])


import xlwt  
workbook=xlwt.Workbook(encoding='utf-8')  
booksheet=workbook.add_sheet('Sheet 1', cell_overwrite_ok=True)  

for i in range(len(county_info)):  
    for j in range(len(county_info[i])):  
        booksheet.write(i,j,county_info[i][j])  
workbook.save('海南省.xls')
# Out:
# 358
# ['海口市', '秀英区', '龙华区', '琼山区', '美兰区']
# ['儋州市']
# ['三亚市']
# ['琼海市']
# ['白沙黎族自治县']
# ['陵水黎族自治县']
